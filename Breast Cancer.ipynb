# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("data.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df['Unnamed: 32']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 564   NaN
# 565   NaN
# 566   NaN
# 567   NaN
# 568   NaN
# Name: Unnamed: 32, Length: 569, dtype: float64

# %%
df = df.drop("Unnamed: 32", axis=1)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
sns.countplot(df['diagnosis'], label="Count",);

# %%
df1 = df.drop(['concavity_se', 'fractal_dimension_se', 'concavity_worst', 'symmetry_worst', 'fractal_dimension_worst', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'smoothness_se', 'compactness_se',  'concave points_se', 'compactness_mean', 'concavity_mean', 'symmetry_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'compactness_worst','concave points_worst'], axis=1)
df1.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  concave points_mean  area_se  area_worst  smoothness_worst
# 0          0.11840              0.14710   153.40      2019.0            0.1622
# 1          0.08474              0.07017    74.08      1956.0            0.1238
# 2          0.10960              0.12790    94.03      1709.0            0.1444
# 3          0.14250              0.10520    27.23       567.7            0.2098
# 4          0.10030              0.10430    94.44      1575.0            0.1374

# %%
df1['diagnosis'] = df['diagnosis'].map({'M':1, 'B':0})
df1.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  concave points_mean  area_se  area_worst  smoothness_worst
# 0          0.11840              0.14710   153.40      2019.0            0.1622
# 1          0.08474              0.07017    74.08      1956.0            0.1238
# 2          0.10960              0.12790    94.03      1709.0            0.1444
# 3          0.14250              0.10520    27.23       567.7            0.2098
# 4          0.10030              0.10430    94.44      1575.0            0.1374

# %%
corr = df1.corr().round(2)
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True);

# %%
plt.hist(df1['diagnosis'])
plt.title('Diagnosis (M=1 , B=0)')
plt.show()

# %% [markdown]
# ## Train Model

# %%
X = df1.drop('diagnosis',axis=1)
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    concave points_mean  area_se  area_worst  smoothness_worst
# 0              0.14710   153.40      2019.0            0.1622
# 1              0.07017    74.08      1956.0            0.1238
# 2              0.12790    94.03      1709.0            0.1444
# 3              0.10520    27.23       567.7            0.2098
# 4              0.10430    94.44      1575.0            0.1374

# %%
y = df['diagnosis']
y.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)
y_pred = dtc.predict(X_test)
y_pred
from sklearn.metrics import accuracy_score,classification_report
dtc_acc = accuracy_score(y_test, y_pred)
print("Accuracy: ",dtc_acc)
print(classification_report(y_test,y_pred))
# Out:
# Accuracy:  0.8951048951048951
#               precision    recall  f1-score   support
#
#            B       0.90      0.93      0.92        91
#            M       0.88      0.83      0.85        52
#
#     accuracy                           0.90       143
#    macro avg       0.89      0.88      0.89       143
# weighted avg       0.89      0.90      0.89       143

# %%
results = pd.DataFrame()
results
tempResults = pd.DataFrame({'Algorithm':['Decision tree Classifier Method'], 'Accuracy':[dtc_acc]})
results = pd.concat( [results, tempResults] )
results = results[['Algorithm','Accuracy']]
results
# Out:
#                          Algorithm  Accuracy
# 0  Decision tree Classifier Method  0.895105

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
y_pred
from sklearn.metrics import accuracy_score,classification_report
rfc_acc = accuracy_score(y_test, y_pred)
print("Accuracy: ",rfc_acc)
print(classification_report(y_test,y_pred))
# Out:
# Accuracy:  0.9440559440559441
#               precision    recall  f1-score   support
#
#            B       0.95      0.97      0.96        91
#            M       0.94      0.90      0.92        52
#
#     accuracy                           0.94       143
#    macro avg       0.94      0.94      0.94       143
# weighted avg       0.94      0.94      0.94       143

# %%
tempResults = pd.DataFrame({'Algorithm':['Random Forest Classifier Method'], 'Accuracy':[rfc_acc]})
results = pd.concat( [results, tempResults] )
results = results[['Algorithm','Accuracy']]
results
# Out:
#                          Algorithm  Accuracy
# 0  Decision tree Classifier Method  0.895105
# 0  Random Forest Classifier Method  0.944056

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn import svm
svc = svm.SVC()
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
y_pred
from sklearn.metrics import accuracy_score, classification_report
svc_acc = accuracy_score(y_test, y_pred)
print("Accuracy: ",svc_acc)
print(classification_report(y_test,y_pred))
# Out:
# Accuracy:  0.9790209790209791
#               precision    recall  f1-score   support
#
#            B       0.97      1.00      0.98        91
#            M       1.00      0.94      0.97        52
#
#     accuracy                           0.98       143
#    macro avg       0.98      0.97      0.98       143
# weighted avg       0.98      0.98      0.98       143

# %%
tempResults = pd.DataFrame({'Algorithm':['Support Vector Classifier Method'], 'Accuracy':[svc_acc]})
results = pd.concat( [results, tempResults] )
results = results[['Algorithm','Accuracy']]
results
# Out:
#                           Algorithm  Accuracy
# 0   Decision tree Classifier Method  0.895105
# 0   Random Forest Classifier Method  0.944056
# 0  Support Vector Classifier Method  0.979021
